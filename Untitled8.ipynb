# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline 
# %reload_ext autoreload
# %autoreload 2

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
cc=sns.load_dataset("car_crashes")
cc.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
#distribution plot univariate 
#shift and tab

# %%
sns.displot(cc["not_distracted"])

# %%
sns.histplot(cc["not_distracted"])
# Out:
# <Axes: xlabel='not_distracted', ylabel='Count'>

# %%
#two compare 2 . joint

# %%
sns.jointplot(x="speeding",y="alcohol",data=cc)

# %%
sns.jointplot(x="speeding",y="alcohol",data=cc,kind="kde")

# %%
sns.jointplot(x="speeding",y="alcohol",data=cc,kind="hex")

# %%
sns.jointplot(x="speeding",y="alcohol",data=cc,kind="reg")

# %%
sns.jointplot(x="speeding",y="alcohol",data=cc,kind="scatter")

# %%
#kde plot
sns.kdeplot(cc["alcohol"])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
#pairplots
sns.pairplot(cc)

# %%
tips=sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue="sex",palette="Blues")

# %%
#rug.
sns.rugplot(tips['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
sns.set_style("white")

# %%
sns.jointplot(x="speeding",y="alcohol",data=cc,kind="reg")

# %%
plt.figure(figsize=(1,2))
sns.set_style("whitegrid")  #dark
sns.jointplot(x="speeding",y="alcohol",data=cc,kind="reg")

# %%
plt.figure(figsize=(20,20))  #not working
sns.set_context("talk",font_scale=1.4)
sns.set_style("ticks")  #not working
sns.jointplot(x="speeding",y="alcohol",data=cc,kind="reg")

# %%
# plt.figure(figsize=(20,20))  #not working
sns.set_context("paper",font_scale=1.4)

sns.jointplot(x="speeding",y="alcohol",data=cc,kind="reg")

# %%
sns.set_context("paper",font_scale=1.4)

sns.jointplot(x="speeding",y="alcohol",data=cc,kind="reg")
sns.despine(left=True)

# %%
sns.set_context("paper",font_scale=1.4)

sns.jointplot(x="speeding",y="alcohol",data=cc,kind="reg")
sns.despine(left=True,bottom=True,right=True,top=True)

# %%
#categoricl.
#bar
sns.barplot(x="sex",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="sex",y="total_bill",data=tips,estimator="median")
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x="sex",y="total_bill",data=tips,estimator=np.median)  #std,var,cov
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#countplot
sns.countplot(x="sex",data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#boxplot
sns.boxplot(x="day",y="total_bill",data=tips,hue="sex")
plt.legend(loc=7) #lefttop  1=righttop  3=downlef   4 5

# %%
#violin # cobination of kde and box plot
sns.violinplot(x="day",y="total_bill",data=tips,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue="sex",split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#stripplot.
sns.stripplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,hue="sex",dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,color="black")
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#Palettes.
# plt.figure(figsize=(8,5))
# sns.set_style("dark")
# sns.set_context("talk")
sns.stripplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_style("darkgrid") # background

sns.stripplot(x="day",y="total_bill",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(10,5))
sns.set_context("paper") # background

sns.stripplot(x="day",y="total_bill",data=tips,hue="sex",palette="afmhot")
#legend=1,2,3,4   6 7  8 9 center      5 right 10 center.  0=best
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#matrixplots

#heatmaps.
# sns.set_context("paper",font_scale=1.4)

sns.lmplot(x="total_bill",y="tip",data=tips,hue="sex",markers=["o","v"],scatter_kws={"s":100})
#palette=coolworm,cmap

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,col="time")

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,col="sex")

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,col="time",row="sex")

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,col="day")

# %%
sns.lmplot(x="total_bill",y="tip",data=tips,col="day",aspect=2,height=30,palette="rainbow")

# %%
tips.head()
cor=tips[["total_bill","tip","size"]].corr()
cor
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(cor,annot=True,cmap="Blues")
# Out:
# <Axes: >

# %%
cc.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [raw]
# f=sns.load_dataset("flights")
#
# f=f.pivot_table(index="month",columns="year",values="passengers")
# f
# sns.heatmap(f,cmap="Blues")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("GAP Prediction.csv")

# %%
data.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
data.isnull().sum()
# Out:
# SAT    0
# GPA    0
# dtype: int64

# %%
data.hist(bins=5)
# Out:
# array([[<Axes: title={'center': 'SAT'}>, <Axes: title={'center': 'GPA'}>]],
#       dtype=object)

# %%
data.corr()
# Out:
#           SAT       GPA
# SAT  1.000000  0.637184
# GPA  0.637184  1.000000

# %%
print(data["SAT"].head())
X=data["SAT"].values.reshape(-1,1)
print(X)
Y=data["GPA"].values.reshape(-1,1)
# Out:
# 0    1714
# 1    1664
# 2    1760
# 3    1685
# 4    1693
# Name: SAT, dtype: int64
# [[1714]
#  [1664]
#  [1760]
#  [1685]
#  [1693]
#  [1670]
#  [1764]
#  [1764]
#  [1792]
#  [1850]
#  [1735]
#  [1775]
#  [1735]
#  [1712]
#  [1773]
#  [1872]
#  [1755]
#  [1674]
#  [1842]
#  [1786]
#  [1761]
#  [1722]
#  [1663]
#  [1687]
#  [1974]
#  [1826]
#  [1787]
#  [1821]
#  [2020]
#  [1794]
#  [1769]
#  [1934]
#  [1775]
#  [1855]
#  [1880]
#  [1849]
#  [1808]
#  [1954]
#  [1777]
#  [1831]
#  [1865]
#  [1850]
#  [1966]
#  [1702]
#  [1990]
#  [1925]
#  [1824]
#  [1956]
#  [1857]
#  [1979]
#  [1802]
#  [1855]
#  [1907]
#  [1634]
#  [1879]
#  [1887]
#  [1730]
#  [1953]
#  [1781]
#  [1891]
#  [1964]
#  [1808]
#  [1893]
#  [2041]
#  [1893]
#  [1832]
#  [1850]
#  [1934]
#  [1861]
#  [1931]
#  [1933]
#  [1778]
#  [1975]
#  [1934]
#  [2021]
#  [2015]
#  [1997]
#  [2020]
#  [1843]
#  [1936]
#  [1810]
#  [1987]
#  [1962]
#  [2050]]

# %%
plt.scatter(X,Y,color='b')
plt.xlabel("SAT")
plt.ylabel("GPA")
# Out:
# Text(0, 0.5, 'GPA')

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
print("xtrain",xtrain.shape)
print("xtest",xtest.shape)
print("ytrain",xtrain.shape)
print("ytest",ytest.shape)
# Out:
# xtrain (63, 1)
# xtest (21, 1)
# ytrain (63, 1)
# ytest (21, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
model=lr.fit(xtrain,ytrain)

# %%
ypred=model.predict(xtest)

# %%
ytest
# Out:
# array([[3.6 ],
#        [2.4 ],
#        [3.47],
#        [3.2 ],
#        [3.08],
#        [3.59],
#        [3.02],
#        [3.17],
#        [2.83],
#        [3.52],
#        [3.37],
#        [3.4 ],
#        [3.31],
#        [3.73],
#        [3.47],
#        [3.44],
#        [3.29],
#        [3.64],
#        [3.38],
#        [3.41],
#        [3.07]])

# %%
ypred
# Out:
# array([[3.47288907],
#        [3.14682824],
#        [3.24612858],
#        [3.07124141],
#        [3.17795223],
#        [3.47140697],
#        [3.17795223],
#        [3.33653636],
#        [3.11570425],
#        [3.32171541],
#        [3.37062454],
#        [3.50549515],
#        [3.34691102],
#        [3.55144009],
#        [3.40323062],
#        [3.39137386],
#        [3.35580359],
#        [3.56626103],
#        [3.5203161 ],
#        [3.53958333],
#        [3.23723601]])

# %%
plt.scatter(X,Y,color='r')
plt.plot(xtest,ypred)
#plt.xlim(100,)
#plt.ylim(0,)
plt.xlabel("SAT")
plt.ylabel("GPA")
# Out:
# Text(0, 0.5, 'GPA')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
r2= r2_score(ytest,ypred)
print("R^2 (coefficient of determination ,)",r2)
# Out:
# R^2 (coefficient of determination ,) 0.48516938725866743

# %%
model.predict([[2500]])
# Out:
# array([[4.31175465]])

# %%
model.coef_
# Out:
# array([[0.00148209]])

# %%
model.intercept_
# Out:
# array([0.60651797])
